# %%
# This program implement cart-pole balancing with random policy
# This program can be run on jupyter notebook or google colab.

# Importing open-ai gym
import gym

# %%
# Creating Cart-Pole environment:
env = gym.make('CartPole-v1')
# Out:
# C:\Users\popoola\AppData\Roaming\Python\Python39\site-packages\gym\utils\passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(

# %%
# Set the number of episodes and number of time steps in the episode
num_episodes = 100
num_timesteps = 50

# %%
# For each episodes
for i in range(num_episodes):
    
    # set the return to zero
    Return = 0
    
    # initialize the state by resetting the environment
    state = env.reset()
    
    # For each step in the episode
    for t in range(num_timesteps):
        # Render the environment
        #env.render()
        
        # Randomly select an action by sampling from the environment
        random_action = env.action_space.sample()
        
        # Perform the randomly selected action:
        next_state, reward, done, info=env.step(random_action)
        
        # Update the return
        Return = Return + reward
        
        # If the next state is a terminal state then end the episode:
        if done:
            break
        
        # For every 15 episodes, print the return(sum of rewards):
        if i%15==0:
            
            # print (Episode, Return)
            print('Episode: {}, Return: {}'. format(i, Return))
        # Close the envronment:
        env.close
# Out:
# Episode: 0, Return: 1.0
# Episode: 0, Return: 2.0
# Episode: 0, Return: 3.0
# Episode: 0, Return: 4.0
# Episode: 0, Return: 5.0
# Episode: 0, Return: 6.0
# Episode: 0, Return: 7.0
# Episode: 0, Return: 8.0
# Episode: 0, Return: 9.0
# Episode: 0, Return: 10.0
# Episode: 0, Return: 11.0
# Episode: 0, Return: 12.0
# Episode: 0, Return: 13.0
# Episode: 0, Return: 14.0
# Episode: 0, Return: 15.0
# Episode: 0, Return: 16.0
# Episode: 0, Return: 17.0
# Episode: 0, Return: 18.0
# Episode: 0, Return: 19.0
# Episode: 0, Return: 20.0
# Episode: 0, Return: 21.0
# Episode: 0, Return: 22.0
# Episode: 0, Return: 23.0
# Episode: 0, Return: 24.0
# Episode: 0, Return: 25.0
# Episode: 15, Return: 1.0
# Episode: 15, Return: 2.0
# Episode: 15, Return: 3.0
# Episode: 15, Return: 4.0
# Episode: 15, Return: 5.0
# Episode: 15, Return: 6.0
# Episode: 15, Return: 7.0
# Episode: 15, Return: 8.0
# Episode: 15, Return: 9.0
# Episode: 15, Return: 10.0
# Episode: 15, Return: 11.0
# Episode: 15, Return: 12.0
# Episode: 15, Return: 13.0
# Episode: 15, Return: 14.0
# Episode: 15, Return: 15.0
# Episode: 15, Return: 16.0
# Episode: 15, Return: 17.0
# Episode: 15, Return: 18.0
# Episode: 15, Return: 19.0
# Episode: 15, Return: 20.0
# Episode: 15, Return: 21.0
# Episode: 15, Return: 22.0
# Episode: 15, Return: 23.0
# Episode: 30, Return: 1.0
# Episode: 30, Return: 2.0
# Episode: 30, Return: 3.0
# Episode: 30, Return: 4.0
# Episode: 30, Return: 5.0
# Episode: 30, Return: 6.0
# Episode: 30, Return: 7.0
# Episode: 30, Return: 8.0
# Episode: 30, Return: 9.0
# Episode: 30, Return: 10.0
# Episode: 45, Return: 1.0
# Episode: 45, Return: 2.0
# Episode: 45, Return: 3.0
# Episode: 45, Return: 4.0
# Episode: 45, Return: 5.0
# Episode: 45, Return: 6.0
# Episode: 45, Return: 7.0
# Episode: 45, Return: 8.0
# Episode: 45, Return: 9.0
# Episode: 45, Return: 10.0
# Episode: 45, Return: 11.0
# Episode: 45, Return: 12.0
# Episode: 45, Return: 13.0
# Episode: 60, Return: 1.0
# Episode: 60, Return: 2.0
# Episode: 60, Return: 3.0
# Episode: 60, Return: 4.0
# Episode: 60, Return: 5.0
# Episode: 60, Return: 6.0
# Episode: 60, Return: 7.0
# Episode: 60, Return: 8.0
# Episode: 60, Return: 9.0
# Episode: 60, Return: 10.0
# Episode: 60, Return: 11.0
# Episode: 60, Return: 12.0
# Episode: 60, Return: 13.0
# Episode: 60, Return: 14.0
# Episode: 75, Return: 1.0
# Episode: 75, Return: 2.0
# Episode: 75, Return: 3.0
# Episode: 75, Return: 4.0
# Episode: 75, Return: 5.0
# Episode: 75, Return: 6.0
# Episode: 75, Return: 7.0
# Episode: 75, Return: 8.0
# Episode: 75, Return: 9.0
# Episode: 75, Return: 10.0
# Episode: 75, Return: 11.0
# Episode: 90, Return: 1.0
# Episode: 90, Return: 2.0
# Episode: 90, Return: 3.0
# Episode: 90, Return: 4.0
# Episode: 90, Return: 5.0
# Episode: 90, Return: 6.0
# Episode: 90, Return: 7.0
# Episode: 90, Return: 8.0
